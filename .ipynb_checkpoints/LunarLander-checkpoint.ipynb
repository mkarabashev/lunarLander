# %%
import gym
env = gym.make('LunarLander-v2')
env.reset()
for _ in range(250):
    env.render()
    env.step(env.action_space.sample()) # take a random action
env.close()
# Out:
# /Users/maksimkarabashev/opt/anaconda3/envs/Jupyter/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
def simulate(genome, net, turns, render, slow = 0):
    env = gym.make(simulation_type)
    observation = env.reset()
    
    for i in range(turns):            
        output = net.activate(observation)[0]

        if output > 0.75:
            output = 1
        elif output <0.25:
            output = -1
        else:
            output = 0
    
        observation, fitness, done, info = env.step(output)
        
        if slow > 0:
            time.sleep(slow)
        
        if render == True:
            env.render()
            
        if done:
            break
    
    env.close()
    return fitness

# %%
import neat
import gym
import numpy as np
import time

num_turns = 200
cur_generation=0
render_generation = 1
min_render_generation = 9
# simulation_type = "LunarLanderContinuous-v2"
# simulation_type = "CartPole-v1"
simulation_type = "Acrobot-v1"

def eval_genomes(genomes, config):
    global cur_generation
    
    for genome_id, genome in genomes:
        genome.fitness = 0
        net = neat.nn.FeedForwardNetwork.create(genome, config)
        fitness = simulate(genome, net, num_turns, False)
        genome.fitness = (fitness)
                
    best_genome = get_best_genome(genomes)
    
    if cur_generation > min_render_generation and cur_generation % render_generation == 0:
        simulate(
            best_genome,
            neat.nn.FeedForwardNetwork.create(best_genome, config),
            num_turns,
            True
        )
        
    cur_generation += 1
    
def get_best_genome(genomes):
    best_genome = None
    max_fitness = -1000
    for genome_id, genome in genomes:
        if max_fitness < genome.fitness:
            max_fitness = genome.fitness
            best_genome = genome
    
    return best_genome
        
def simulate(genome, net, turns, render, slow = 0):
    env = gym.make(simulation_type)
    observation = env.reset()
    
    for i in range(turns):            
        output = net.activate(observation)[0]

        if output > 0.75:
            output = 1
        elif output <0.25:
            output = -1
        else:
            output = 0
    
        observation, fitness, done, info = env.step(output)
        
        if slow > 0:
            time.sleep(slow)
        
        if render == True:
            env.render()
            
        if done:
            break
    
    env.close()
    return fitness
    
        
def run(config_file):
    # Load configuration.
    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         config_file)

    # Create the population, which is the top-level object for a NEAT run.
    p = neat.Population(config)

    # Add a stdout reporter to show progress in the terminal.
    p.add_reporter(neat.StdOutReporter(True))
    stats = neat.StatisticsReporter()
    p.add_reporter(stats)
    p.add_reporter(neat.Checkpointer(5))

    # Run for up to 300 generations.
    winner = p.run(eval_genomes, 500)
    return winner


best = run('neat_acrobot.cfg')
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: -0.90500 stdev: 0.29321
# Best fitness: 0.00000 - size: (1, 6) - species 1 - id 41
#
# Best individual in generation 0 meets fitness threshold - complexity: (1, 6)

# %%
config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                     neat.DefaultSpeciesSet, neat.DefaultStagnation,
                     'neat_acrobot.cfg')
simulate(
    best,
    neat.nn.FeedForwardNetwork.create(best, config),
    num_turns,
    True,
    0.03
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e8aaa467d091> in <module>
#       7     num_turns,
#       8     True,
# ----> 9     0.03
#      10 )
#
# <ipython-input-3-8e3613ad3ed7> in simulate(genome, net, turns, render, slow)
#      60
#      61         if slow > 0:
# ---> 62             time.sleep(slow)
#      63
#      64         if render == True:
#
# KeyboardInterrupt:

# %%
import neat
import gym
import numpy as np
import time

num_turns = 500
cur_generation=0
render_generation = 10
min_render_generation = 20
# simulation_type = "LunarLanderContinuous-v2"
# simulation_type = "CartPole-v1"
simulation_type = "MountainCarContinuous-v0"

def eval_genomes(genomes, config):
    global cur_generation
    
    for genome_id, genome in genomes:
        genome.fitness = 0
        net = neat.nn.FeedForwardNetwork.create(genome, config)
        fitness = simulate(genome, net, num_turns, False)
        genome.fitness = fitness
                
    best_genome = get_best_genome(genomes)
    
    if cur_generation > min_render_generation and cur_generation % render_generation == 0:
        simulate(
            best_genome,
            neat.nn.FeedForwardNetwork.create(best_genome, config),
            num_turns,
            True
        )
        
    cur_generation += 1
    
def get_best_genome(genomes):
    best_genome = None
    max_fitness = -1000
    for genome_id, genome in genomes:
        if max_fitness < genome.fitness:
            max_fitness = genome.fitness
            best_genome = genome
    
    return best_genome
        
def simulate(genome, net, turns, render, slow = 0):
    env = gym.make(simulation_type)
    observation = env.reset()

    for i in range(turns):            
        output = net.activate(observation)
        modified_output = [output[0] * 2 - 1]
        observation, fitness, done, info = env.step(modified_output)
        
        if slow > 0:
            time.sleep(slow)

        if render == True:
            env.render()
            
        if done:
            break
    
    env.close()
    return fitness + 100 * abs(observation[0])
    
        
def run(config_file):
    # Load configuration.
    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         config_file)

    # Create the population, which is the top-level object for a NEAT run.
    p = neat.Population(config)

    # Add a stdout reporter to show progress in the terminal.
    p.add_reporter(neat.StdOutReporter(True))
    stats = neat.StatisticsReporter()
    p.add_reporter(stats)
    p.add_reporter(neat.Checkpointer(5))

    # Run for up to 300 generations.
    winner = p.run(eval_genomes, 500)
    return winner


best = run('neat_mountain.cfg')

# %%
config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                     neat.DefaultSpeciesSet, neat.DefaultStagnation,
                     'neat_mountain.cfg')
simulate(
    best,
    neat.nn.FeedForwardNetwork.create(best, config),
    num_turns,
    True,
)

# %%
import neat
import gym
import numpy as np
import time

num_turns = 250
cur_generation=0
render_generation = 3
min_render_generation = 4
simulation_type = "LunarLanderContinuous-v2"
# simulation_type = "CartPole-v1"
# simulation_type = "MountainCarContinuous-v0"

def eval_genomes(genomes, config):
    global cur_generation
    
    for genome_id, genome in genomes:
        genome.fitness = 0
        net = neat.nn.FeedForwardNetwork.create(genome, config)
        fitness = simulate(genome, net, num_turns, False)
        genome.fitness = fitness
                
    best_genome = get_best_genome(genomes)
    
    if cur_generation > min_render_generation and cur_generation % render_generation == 0:
        simulate(
            best_genome,
            neat.nn.FeedForwardNetwork.create(best_genome, config),
            num_turns,
            True
        )
        
    cur_generation += 1
    
def get_best_genome(genomes):
    best_genome = None
    max_fitness = -1000
    for genome_id, genome in genomes:
        if max_fitness < genome.fitness:
            max_fitness = genome.fitness
            best_genome = genome
    
    return best_genome
        
def simulate(genome, net, turns, render, slow = 0):
    env = gym.make(simulation_type)
    observation = env.reset()

    for i in range(turns):            
        output = net.activate(observation)
        observation, fitness, done, info = env.step([i*2-1 for i in output])
        
        if slow > 0:
            time.sleep(slow)

        if render == True:
            env.render()
            
        if done:
            return 200
    
    env.close()
    return fitness - 10 * observation[1] - abs(observation[0]) - observation[2]
    
        
def run(config_file):
    # Load configuration.
    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         config_file)

    # Create the population, which is the top-level object for a NEAT run.
    p = neat.Population(config)

    # Add a stdout reporter to show progress in the terminal.
    p.add_reporter(neat.StdOutReporter(True))
    stats = neat.StatisticsReporter()
    p.add_reporter(stats)
    p.add_reporter(neat.Checkpointer(5))

    # Run for up to 300 generations.
    winner = p.run(eval_genomes, 500)
    return winner


best = run('neat_lander.cfg')
# Out:
#  ****** Running generation 0 ******
# /Users/maksimkarabashev/opt/anaconda3/envs/Jupyter/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Population's average fitness: -104.59329 stdev: 7.51565
# Best fitness: -96.15999 - size: (2, 16) - species 1 - id 13
# Average adjusted fitness: 0.726
# Mean genetic distance 1.203, standard deviation 0.293
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0   100    -96.2    0.726     0
# Total extinctions: 0
# Generation time: 2.908 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: -103.89989 stdev: 9.42143
# Best fitness: -97.06125 - size: (2, 15) - species 1 - id 113
# Average adjusted fitness: 0.887
# Mean genetic distance 1.152, standard deviation 0.335
# ...
